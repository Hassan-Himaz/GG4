# %% [markdown]
# # Week 1: System exploration (Group)
#
# In the first stage, your aim is to **understand the behaviour of a system**.
#
# You should focus on questions like:
# - How do the observed signals change over time?
# - How do different input patterns affect the observations?
# - Are some signals more informative than others?
# - What is easy to observe, and what seems hidden?
#
# At this stage, the priority is **exploration and intuition-building**, not solving the whole project.
#
# ## Group tasks for Week 1
#
# As a group, extend the basic experiment and **build a shared code workflow.**
#
# Your group should aim to produce:
# - a clean way to explore dataset, either from simulation or experiment,
# - standard plotting functions,
# - a simulation platform for studying and comparing effects of different input patterns and system dynamics (transition matrices), for example:
#     - random inputs,
#     - pulses,
#     - oscillatory inputs,
#     - activating only one input channel at a time,
#     - activating different channels with different amplitudes,
#     - exploring the relationship between input structure and system dynamics (such as coupling between inputs and transition matrices);
# - brief documentation so that all group members can build on the same starting point.
#
# All of the above tasks should be completed by Friday 22 May, before the scheduled check-in session.
#
# ## Week 1 deliverable
#
# **Deliverable:** Group simulation code + brief documentation
# **Marks:** 10 group marks
# **Due:** Friday 22 May, 11am–1pm (**compulsory session**)
#
# At the check-in session, the demonstrator will review the code and ask each member of the group questions about it. Every member of the group is therefore expected to have contributed to the code and to take full responsibility for understanding it.

# %% [markdown]
# ## Example dataset

# %%
# loading dataset
import numpy as np
data = np.load("ExampleDataset.npy")
print("Dataset loaded successfully. Shape:", data.shape)  # (Trials, Timepoints, Neurons) - so we batch 
print(data[0])
# Out:
# Dataset loaded successfully. Shape: (5, 60, 16)
# [[-0.8889  1.7296  0.4622  0.0525 -1.247  -0.2441  0.8517  0.6852  0.4744
#   -1.124  -1.0022 -0.1156  0.1574 -1.      0.6447  1.7137]
#  [-0.8748  0.4886  0.3413  0.6858 -0.0532  0.0463 -0.2937  0.7804 -1.5687
#   -1.3806  3.1986 -1.3508 -0.4305  0.0913 -0.7989 -0.3906]
#  [-1.7925  0.2714 -0.885  -0.1019  0.4019 -0.4239  0.6033  0.7057 -1.1167
#    0.4631  0.5402 -0.9151 -0.9003  0.3006  0.0647  1.0524]
#  [ 0.6262  0.9334  0.514  -1.4308  1.009   0.2443  0.2268  0.6924 -0.327
#    1.3215  0.2865 -0.7584  1.0433  0.2449  2.5637 -0.4162]
#  [-1.425   1.8933  0.9413  1.1345  0.3524  0.8979  0.1971 -1.5855  1.2968
#   -0.9145  0.2173 -0.5416 -0.4463  1.8641  2.6466 -0.053 ]
#  [ 0.4043  0.0589 -2.1273 -0.6587  0.2251  0.6801 -1.3632  2.0475 -0.2664
#   -1.1292 -0.08   -2.0883 -1.4482 -0.0604 -1.4517  0.9492]
#  [-0.0595  0.5832  0.2277 -1.5795  0.4001 -0.4537  0.333   1.2723 -0.9092
# ...

# %% [markdown]
# ## Desgin an illustrator
#
# A class that can generate primary statistics, analyses, and visualization of any dataset. Design your illustrator in **Illustrator.py**.
#
# To test your documentation, the demonstrator will use your illustrator here, but will never see your code (in this section).
#
# Please make your annotations clear and comprehensive!

# %%
from Illustrator import Illustrator

illustrator = Illustrator(data)
illustrator.spam_everything()

pass
# Out:
# Dataset summary
# ----------------
# Number of trials: 5
# Number of timepoints per trial: 60
# Number of neurons/signals: 16
# Overall mean: 3.2349
# Overall standard deviation: 3.0061
# Minimum value: -2.9995
# Maximum value: 11.1942
# Neuron statistics
# -----------------
# Neuron  0: mean=3.292, std=3.331, var=11.094, peak=9.791, peak_time=39peak_slope = 2.2402125992304467
# Neuron  1: mean=3.233, std=2.849, var=8.118, peak=9.424, peak_time=36peak_slope = 1.4316570382536784
# Neuron  2: mean=3.404, std=3.026, var=9.159, peak=9.832, peak_time=35peak_slope = 1.0348063552761595
# Neuron  3: mean=2.293, std=2.171, var=4.715, peak=6.911, peak_time=39peak_slope = 0.9446217338097322
# Neuron  4: mean=3.500, std=3.170, var=10.048, peak=9.746, peak_time=37peak_slope = 1.4400836771099854
# Neuron  5: mean=3.345, std=2.983, var=8.897, peak=10.161, peak_time=39peak_slope = 1.3241810332742252
# ...

# %% [markdown]
# ## Design a simulator
#
# In GG4, we use a simple linear model:
# $$
# x_{t+1} = Ax_t + Bu_t + w_t, w_t \sim \mathcal{N}(0, Q)
# $$
# $$
# y_t = Cx_t + o_t, o_t \sim \mathcal{N}(0, R)
# $$
#
# Your simulator should be able to simulate observation of any length given different parameters.
#
# Design your simulator in **Simulator.py**.
#
# To test your documentation, the demonstrator will use your simulator here, but will never see your code (in this section).
# Please make your annotations clear and comprehensive!
#
# Combining the illustrator and simulator, what's your findings? Illustrate them.
# This forms your answer to the question: "effects of different input patterns and system dynamics"

# %%
import Simulator_Yuming

importlib.reload(Simulator_Yuming)

print(Simulator_Yuming.__file__)
print(dir(Simulator_Yuming))

from Simulator_Yuming import Simulator2
# Out:
# /Users/ameciouslee/Desktop/IIA/GG4/GG4/Simulator_Yuming.py
# ['Simulator2', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'np', 'plt']

# %%
import Simulator_Yuming
print(Simulator_Yuming.__file__)

from Simulator_Yuming import Simulator2
# Out:
# /Users/ameciouslee/Desktop/IIA/GG4/GG4/Simulator_Yuming.py

# %%
# 1. Whether A is non-normal
# 2. Whether A's eigenbasis is ill-conditioned
# 3. Whether A^t has a transient amplification
# 4. Check controllable / observable / Grammian



# normal condition: AA^T=A^TA  so non_normality larger -- more non normal
# whether the peak comes from non-normal dynamics?
def non_normality(A):
    return np.linalg.norm(A @ A.T - A.T @ A)

# wether there is severe mode mixing?
def eigenbasis_condition(A):
    # diagnolise
    _, V = np.linalg.eig(A)
    # condition number
    return np.linalg.cond(V)

# whether there is transient amplification and how large is the peak?
def matrix_power_norms(A, horizon=40):
    norms, Ak = [], np.eye(A.shape[0])
    for _ in range(horizon + 1):
        norms.append(np.linalg.norm(Ak, ord=2))
        Ak = Ak @ A
    return np.array(norms)

def plot_power_norms(A, horizon=40, title="‖Aᵗ‖₂"):
    norms = matrix_power_norms(A, horizon)
    plt.figure(figsize=(7, 3))
    plt.plot(norms)
    # Reference Larger than 1: transient amplification exsit
    plt.axhline(1, color="gray", linestyle="--", linewidth=0.8)

    plt.xlabel("t")
    plt.ylabel("‖Aᵗ‖₂")
    plt.title(title)
    plt.tight_layout()
    plt.show()
    # amplitude of peak + step occuring
    print(f"Peak ‖Aᵗ‖₂ = {norms.max():.3f} at t = {norms.argmax()}")

def quick_report(sim, name="System", horizon=30):
    eigvals = np.linalg.eigvals(sim.A)
    gram = sim.gramian_summary(horizon=horizon)
    print(f"\n{'='*55}")
    print(f"  {name}")
    print(f"{'='*55}")
    print(f"  Dims          state={sim.state_dim}, input={sim.input_dim}, output={sim.output_dim}")
    print(f"  Eigenvalues   {eigvals}")
    print(f"  Spectral r    {np.max(np.abs(eigvals)):.4f}  →  stable={sim.is_stable()}")
    print(f"  Non-normal    {non_normality(sim.A):.4f}")
    print(f"  Eig cond      {eigenbasis_condition(sim.A):.2f}")
    print(f"  Controllable  {sim.is_controllable()}  (rank {sim.controllability_rank()}/{sim.state_dim})")
    print(f"  Observable    {sim.is_observable()}  (rank {sim.observability_rank()}/{sim.state_dim})")
    print(f"  Wc eigs       {gram['eig_Wc']}")
    print(f"  Wo eigs       {gram['eig_Wo']}")
    print(f"{'='*55}\n")
    plot_power_norms(sim.A, horizon=horizon, title=f"{name}: ‖Aᵗ‖₂")

# %%
def make_simple_baseline():
# a random system which is simple and stable, with input noise and observation noise,  as for reference
    A = np.array([[0.85, 0.00],
                  [0.00, 0.55]])

    B = np.array([[1.00],
                  [0.40]])

    C = np.eye(2)

    return Simulator2({"A": A, "B": B, "C": C,
                      "Q": 0.002*np.eye(2),
                      "R": 0.002*np.eye(2),
                      "x0": np.zeros(2),
                      "seed": 0})


def make_non_normal():
    # very typical: eigenvalues < 1 but transient pulse exists
    A = np.array([[0.8, 6.0],
                  [0.0, 0.7]])
    B = np.array([[0.0], [1.0]])
    C = np.eye(2)
    x0 = np.array([0.0, 1.0])  
    return Simulator2({"A": A, "B": B, "C": C,
                      "Q": np.zeros((2,2)), "R": np.zeros((2,2)),
                      "x0": x0, "seed": 1})


def make_obs_nullspace():
    # C = [1, 0]：observation can only see x₁
    # B = [0, 1]ᵀ：input goes into x₂
    # y should has no response at the start
    # A_12=1 transfer to x1
    A = np.array([[0.8, 1.0],
                  [0.0, 0.6]])
    B = np.array([[0.0], [1.0]])
    C = np.array([[1.0, 0.0]])
    return Simulator2({"A": A, "B": B, "C": C,
                      "Q": np.zeros((2,2)), "R": np.zeros((1,1)),
                      "x0": np.zeros(2), "seed": 2})


# eigenvectors almost parallel
def make_ill_conditioned():
    # Diagonlise A = V Λ V⁻¹
    # V columns are almost parallel（epsilon very small），so condition number of V is large
    # Λ = diag(0.95, 0.55)，eigenvalues stable
    eps = 0.03
    V = np.array([[1.0, 1.0],
                  [0.0, eps]])
    A = V @ np.diag([0.95, 0.55]) @ np.linalg.inv(V)
    B, C = np.eye(2), np.eye(2)
    return Simulator2({"A": A, "B": B, "C": C,
                      "Q": 0.05*np.eye(2), "R": np.zeros((2,2)),
                      "x0": np.zeros(2), "seed": 3})

# when input freq = system freq, resonance occurs
def make_oscillator(radius=0.93, theta=0.3*np.pi):
    A = radius * np.array([[np.cos(theta), -np.sin(theta)],
                           [np.sin(theta),  np.cos(theta)]])
    B = np.array([[1.0], [0.0]])
    C = np.eye(2)
    return Simulator2({"A": A, "B": B, "C": C,
                      "Q": 0.005*np.eye(2), "R": 0.005*np.eye(2),
                      "x0": np.zeros(2), "seed": 4})

# %%
sim_base = make_simple_baseline()
quick_report(sim_base, name="Simple stable baseline system")

T = 80

U = sim_base.generate_input(
    T,
    pattern="pulse",
    amplitude=2.0,
    pulse_time=10,
    pulse_width=5
)

result = sim_base.simulate(
    T,
    U=U,
    process_noise=True,
    observation_noise=True
)

sim_base.plot_simulation(result, title="Simple baseline — pulse input")
# Out:
# ...
#   Simple stable baseline system
# ...
#   Dims          state=2, input=1, output=2
#   Eigenvalues   [0.85 0.55]
#   Spectral r    0.8500  →  stable=True
#   Non-normal    0.0000
#   Eig cond      1.00
#   Controllable  True  (rank 2/2)
#   Observable    True  (rank 2/2)
#   Wc eigs       [0.0697 3.7631]
#   Wo eigs       [1.4337 3.6034]
# ...
# Peak ‖Aᵗ‖₂ = 1.000 at t = 0

# %% [markdown]
# This cell gives a simple stable system as a reference.
#
# The system has two hidden states and one input. The matrix \(A\) is diagonal, so the two states are easy to understand separately. Both eigenvalues are less than 1, so both states decay over time.
#
# A pulse input is used because it is easier to see the system response. After the pulse, the hidden states increase and then slowly return towards zero. This shows the basic behaviour of a stable system: input can create a temporary response, but the response does not grow forever.
#
# The observation matrix is \(C=I\), so the observations directly show the hidden states. This makes the plots easier to read.
#
# This cell is used as a clean reference before studying more complicated systems.

# %%
# transient peak without any input!
sim_nn = make_non_normal()
quick_report(sim_nn, name="Non-normal system")

T = 40
U_zero = sim_nn.generate_input(T, pattern="zero")
result_nn = sim_nn.simulate(T, U=U_zero, process_noise=False, observation_noise=False)
sim_nn.plot_simulation(result_nn, title="Non-normal — zero input, x₀=[0,1]")
# Out:
# ...
#   Non-normal system
# ...
#   Dims          state=2, input=1, output=2
#   Eigenvalues   [0.8 0.7]
#   Spectral r    0.8000  →  stable=True
#   Non-normal    50.9188
#   Eig cond      120.01
#   Controllable  True  (rank 2/2)
#   Observable    True  (rank 2/2)
#   Wc eigs       [  1.4558 695.6773]
#   Wo eigs       [  1.4578 698.453 ]
# ...
# Peak ‖Aᵗ‖₂ = 10.181 at t = 4

# %% [markdown]
# This cell shows that a stable system can still have a large temporary response.
#
# The system has zero input, so any activity in the state must come from the initial condition and the internal dynamics of \(A\). This is why the input plot is flat at zero.
#
# The eigenvalues of \(A\) are 0.8 and 0.7, so the system is stable in the long run. However, \(A\) has a large off-diagonal value. This means that the second state strongly affects the first state.
#
# The system starts from \(x_0=[0,1]\). The second state \(x_2\) slowly decays, but while it is decaying, it pushes the first state \(x_1\) upward. Because of this, \(x_1\) first grows to a large value and only later decays back towards zero.
#
# The plot of \(\|A^t\|_2\) shows the same idea. It rises to a large peak before falling, which means the system can temporarily amplify some directions even though it is stable.
#
# The observation plot looks the same as the hidden state plot because \(C=I\), so the hidden states are directly observed.
#
# The main point of this cell is that stability only describes the long-term behaviour. It does not mean the state must decrease immediately at every time step.

# %%
sim_ns = make_obs_nullspace()
quick_report(sim_ns, name="Input into observation null-space")

# CB 衡量 input 对 observation 的即时效果
# 如果 CB ≈ 0，input 当下对 y 没有直接影响
print("CB =", sim_ns.C @ sim_ns.B)

T = 50
U_pulse = sim_ns.generate_input(T, pattern="pulse",
                                 amplitude=5.0, pulse_time=10, pulse_width=1)
result_ns = sim_ns.simulate(T, U=U_pulse, process_noise=False, observation_noise=False)
sim_ns.plot_simulation(result_ns, title="Observation null-space — pulse at t=10")
# Out:
# ...
#   Input into observation null-space
# ...
#   Dims          state=2, input=1, output=1
#   Eigenvalues   [0.8 0.6]
#   Spectral r    0.8000  →  stable=True
#   Non-normal    1.4422
#   Eig cond      10.10
#   Controllable  True  (rank 2/2)
#   Observable    True  (rank 2/2)
#   Wc eigs       [ 1.2692 12.6462]
#   Wo eigs       [ 1.1479 13.9828]
# ...
# Peak ‖Aᵗ‖₂ = 1.579 at t = 3
# CB = [[0.]]

# %% [markdown]
# This cell studies a case where the input is not seen immediately in the output.
#
# The input pulse happens at \(t=10\). It goes directly into the second hidden state \(x_2\), so \(x_2\) responds immediately. However, the observation only measures \(x_1\), not \(x_2\). This is why the output does not change at the same moment as the input.
#
# After that, the effect of \(x_2\) is passed to \(x_1\) through the system dynamics, so both \(x_1\) and the output rise later. The main idea is that a weak or delayed observation does not mean the input had no effect. It may simply have entered a direction that is not directly observed.

# %%
sim_ill = make_ill_conditioned()
quick_report(sim_ill, name="Ill-conditioned eigenbasis")

T = 300
U_zero = sim_ill.generate_input(T, pattern="zero")
# set process noise to observe variance
result_ill = sim_ill.simulate(T, U=U_zero, process_noise=True, observation_noise=False)
sim_ill.plot_simulation(result_ill, title="Ill-conditioned — balanced noise input")

X = result_ill["X"]
var = np.var(X, axis=0)
print("Latent coordinate variances:", var)

plt.figure(figsize=(5, 3))
plt.bar(range(len(var)), var)
plt.xlabel("Latent coordinate")
plt.ylabel("Variance")
plt.title("Variance per latent coordinate")
plt.tight_layout()
plt.show()
# Out:
# ...
#   Ill-conditioned eigenbasis
# ...
#   Dims          state=2, input=2, output=2
#   Eigenvalues   [0.95 0.55]
#   Spectral r    0.9500  →  stable=True
#   Non-normal    251.5289
#   Eig cond      66.68
#   Controllable  True  (rank 2/2)
#   Observable    True  (rank 2/2)
#   Wc eigs       [   1.3717 7819.9677]
#   Wo eigs       [   1.3717 7819.9677]
# ...
# Peak ‖Aᵗ‖₂ = 24.128 at t = 5
# Latent coordinate variances: [391.5117   0.0689]

# %% [markdown]
# This cell shows that balanced noise does not always create balanced state behaviour.
#
# There is no external input in this simulation. The input plot is flat at zero. Instead, the system is driven only by process noise. The process noise is balanced, because \(Q=0.05I\), so both state coordinates receive noise with the same strength.
#
# The system is still stable, since the eigenvalues of \(A\) are 0.95 and 0.55. However, the eigenvectors of \(A\) are almost parallel, so the eigenbasis is ill-conditioned. This means the coordinate system is badly stretched.
#
# Because of this, the same balanced noise appears very differently in the two state coordinates. In the hidden state plot, \(x_1\) has very large fluctuations, while \(x_2\) stays close to zero. The variance plot confirms this: the variance of \(x_1\) is much larger than the variance of \(x_2\).
#
# The observation plot looks the same as the hidden state plot because \(C=I\), so the states are directly observed.
#
# The main point is that large variance in one coordinate does not necessarily mean that the input or noise was stronger in that coordinate. It can also be caused by the geometry of \(A\).

# %%
sim_inp = make_simple_baseline()
T = 100

# 每种 pattern 的参数不一样，所以用 list of (pattern, kwargs) 来组织
patterns_kwargs = [
    ("zero",          {}),
    ("random",        {}),
    ("pulse",         {"amplitude": 2.0, "pulse_time": 20, "pulse_width": 5}),
    ("sine",          {"amplitude": 1.0, "frequency": 0.05}),
    ("single_channel",{"amplitude": 1.0, "channel": 0}),
    ("step",          {"amplitude": 1.0, "pulse_time": 30}),
]

for pattern, kwargs in patterns_kwargs:
    U = sim_inp.generate_input(T, pattern=pattern, **kwargs)
    result = sim_inp.simulate(T, U=U, process_noise=False, observation_noise=False)
    sim_inp.plot_simulation(result, title=f"Input pattern: {pattern}")

# %% [markdown]
# ## Comparing Different Input Patterns
#
# This cell uses the same stable system, but applies different types of input to it. The goal is to see how the shape of the input changes the hidden states and observations.
#
# There is no process noise or observation noise in this cell, so the responses come only from the input and the system dynamics.
#
# For zero input, the hidden state and observation stay at zero. This is a simple check that nothing happens when there is no input, no noise, and zero initial state.
#
# For random input, the system is continuously driven by changing input values. The hidden states and observations move around, but they stay bounded because the system is stable.
#
# For pulse input, the input is only active for a short time. The hidden states respond during the pulse and then decay back toward zero after the pulse ends. This shows the transient response of the system.
#
# For sine input, the input changes periodically. The hidden states and observations also become periodic, but with different amplitudes and phases because the input is filtered through the system dynamics.
#
# For single-channel input, only one input channel is turned on. This shows which hidden states and observations are affected by that particular input channel.
#
# For step input, the input changes from zero to a constant value. The system first has a transient response and then settles to a new steady state.
#
# Overall, this cell shows that the same stable system can look very different depending on the input pattern.

# %%
sim_osc = make_oscillator(radius=0.93, theta=0.3*np.pi)
quick_report(sim_osc, name="Oscillatory system")

# 从 eigenvalue 的 angle 计算系统自然频率
eigvals = np.linalg.eigvals(sim_osc.A)
# 取复数 eigenvalue 的辐角，换算成 cycles/step
natural_freq = np.abs(np.angle(eigvals[0])) / (2 * np.pi)
print(f"Natural frequency ≈ {natural_freq:.4f} cycles/step")

T = 150
for freq in [0.02, natural_freq, 0.35]:
    U = sim_osc.generate_input(T, pattern="sine", amplitude=1.0, frequency=freq)
    result = sim_osc.simulate(T, U=U, process_noise=False, observation_noise=False)
    sim_osc.plot_simulation(result,
        title=f"f={freq:.3f}  (natural≈{natural_freq:.3f})")
# Out:
# ...
#   Oscillatory system
# ...
#   Dims          state=2, input=1, output=2
#   Eigenvalues   [0.5466+0.7524j 0.5466-0.7524j]
#   Spectral r    0.9300  →  stable=True
#   Non-normal    0.0000
#   Eig cond      1.00
#   Controllable  True  (rank 2/2)
#   Observable    True  (rank 2/2)
#   Wc eigs       [3.3267 3.9801]
#   Wo eigs       [7.3068 7.3068]
# ...
# Peak ‖Aᵗ‖₂ = 1.000 at t = 0
# Natural frequency ≈ 0.1500 cycles/step

# %% [markdown]
# ##  Oscillatory System and Natural Frequency
#
# This cell studies a stable oscillatory system.
#
# The matrix \(A\) is a scaled rotation matrix. This means the state rotates at each time step, but the radius is multiplied by 0.93, so the motion slowly decays. The system is stable because the eigenvalues have magnitude 0.93, which is less than 1.
#
# The eigenvalues are complex, so the system has an internal oscillation. The angle of the eigenvalue gives the natural frequency of the system. In this case, the natural frequency is about 0.15 cycles per step.
#
# The code then applies sine inputs with three different frequencies: a low frequency, the natural frequency, and a higher frequency. The aim is to see how the system response changes when the input frequency changes.
#
# When the input frequency is close to the natural frequency, the response should be stronger. This is similar to resonance. The system is stable, so the response does not grow forever, but it can still have a larger amplitude at the matching frequency.
#
# This example is different from the non-normal and ill-conditioned examples. Here the main effect comes from complex eigenvalues and oscillation, not from badly aligned eigenvectors.
